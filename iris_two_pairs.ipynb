# %% [markdown]
# <a href="https://colab.research.google.com/github/palxx/cs164_prep/blob/main/iris_two_pairs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab Notebooks
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks

# %%
# Import the necessary modules
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
import seaborn as sns


# Read in the file fg_attempt.csv
iris_dataset = pd.read_csv('iris_data.csv')

print (f"{iris_dataset.shape}")
x1Name = 'petal_length'
x2Name = 'petal_width'
x3Name = 'sepal_length'
x4Name = 'sepal_width'

# Select the two features you want
X = iris_dataset[[x1Name, x2Name]]

# Create a dataframe y containing 'class'
y = iris_dataset[['class']]

# Flatten y into an array
yArray = np.ravel(y)

# Initialize a LogisticRegression() model
logisticModel = LogisticRegression()

# Fit the model
logisticModel.fit(X, yArray)

# Input feature values for a sample instance

x1 = float(input())
x2 = float(input())

# Create a new dataframe with user-input Distance and ScoreDiffPreKick
XNew = pd.DataFrame([{x1Name: x1, x2Name: x2}])

# Predict the outcome from the new data
pred = logisticModel.predict(XNew)
print(pred)

# Determine the accuracy of the model logisticModel
score = logisticModel.score(X, yArray)
print(f"{score:.2f}")
# Out:
# (150, 5)
# 1
# 2
# ['Iris-setosa']
# 0.97

# %% [markdown]
# # New Section

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X[x1Name], X[x2Name], c='blue', label='Petal Data')
plt.xlabel(x1Name)
plt.ylabel(x2Name)
plt.title('Scatter Plot of Petal Length vs Petal Width')
plt.legend()
plt.grid(True)
plt.show()

# %%
X = iris_dataset[[x2Name, x3Name]]
logisticModel.fit(X, yArray)
score = logisticModel.score(X, yArray)
print(f"{score:.2f}")
# Out:
# 0.96

# %%
X = iris_dataset[[x2Name, x4Name]]
logisticModel.fit(X, yArray)
score = logisticModel.score(X, yArray)
print(f"{score:.2f}")
# Out:
# 0.96

# %%
X = iris_dataset[[x1Name, x2Name]]
logisticModel.fit(X, yArray)
score = logisticModel.score(X, yArray)
print(f"{score:.2f}")
# Out:
# 0.97

# %%
X = iris_dataset[[x1Name, x3Name]]
logisticModel.fit(X, yArray)
score = logisticModel.score(X, yArray)
print(f"{score:.2f}")
# Out:
# 0.96

# %%
X = iris_dataset[[x1Name, x4Name]]
logisticModel.fit(X, yArray)
score = logisticModel.score(X, yArray)
print(f"{score:.2f}")
# Out:
# 0.95

# %%
X = iris_dataset[[x3Name, x4Name]]
logisticModel.fit(X, yArray)
score = logisticModel.score(X, yArray)
print(f"{score:.2f}")
# Out:
# 0.82
